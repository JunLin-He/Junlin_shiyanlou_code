# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("los_census.csv")

# %%
pd.read_table("los_census.txt", sep=',')
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0       91371                 1        73.5            0              1
# 1       90001             57110        26.6        28468          28642
# 2       90002             51223        25.5        24876          26347
# 3       90003             66266        26.3        32631          33635
# 4       90004             62180        34.8        31302          30878
# 5       90005             37681        33.9        19299          18382
# 6       90006             59185        32.4        30254          28931
# 7       90007             40920        24.0        20915          20005
# 8       90008             32327        39.7        14477          17850
# 9       90010              3800        37.8         1874           1926
# 10      90011            103892        26.2        52794          51098
# 11      90012             31103        36.3        19493          11610
# ...

# %%
pd.read_csv("los_census.csv", names=['A', 'B', 'C', 'D', 'E', 'F', 'G'])
# Out:
#             A                 B           C            D              E  \
# 0    Zip Code  Total Population  Median Age  Total Males  Total Females
# 1       91371                 1        73.5            0              1
# 2       90001             57110        26.6        28468          28642
# 3       90002             51223        25.5        24876          26347
# 4       90003             66266        26.3        32631          33635
# 5       90004             62180        34.8        31302          30878
# 6       90005             37681        33.9        19299          18382
# 7       90006             59185        32.4        30254          28931
# 8       90007             40920          24        20915          20005
# 9       90008             32327        39.7        14477          17850
# 10      90010              3800        37.8         1874           1926
# 11      90011            103892        26.2        52794          51098
# ...

# %%
# 读取csv文件，并将其存储为json格式
df_los_census = pd.read_csv("los_census.csv")
df_los_census.to_json("1.json")

# %%
# !ls | grep json
# Out:
# 1.json

# %%
df_los_census.to_excel("1.xlsx")

# %%
# !ls
# Out:
# 1. Pandas_Installation&DataStructure.ipynb
# 1.json
# 1.xlsx
# 2. Pandas_BasicMethod.ipynb
# los_census.csv
# los_census.txt

# %%
# !open 1.xlsx

# %%
# head() 默认显示头部的5条数据
df_los_census.head(7)
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
# 5     90005             37681        33.9        19299          18382
# 6     90006             59185        32.4        30254          28931
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36
# 3             15642                    4.22
# 4             22547                    2.73
# 5             15044                    2.50
# 6             18617                    3.13

# %%
# tail() 方法就是从数据集尾部开始显示了，同样默认 5 条
df_los_census.tail(7)
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 312     93550             74929        27.5        36414          38515
# 313     93551             50798        37.0        25056          25742
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 312             20864                    3.58
# 313             15963                    3.18
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67

# %%
##### 统计方法 ######

# %%
# 1.describe() 相当于对数据集进行概览，会输出该数据集的计数、最大值、最小值等。
df_los_census.describe()
# Out:
#            Zip Code  Total Population  Median Age   Total Males  \
# count    319.000000        319.000000  319.000000    319.000000
# mean   91000.673981      33241.341693   36.527586  16391.564263
# std      908.360203      21644.417455    8.692999  10747.495566
# min    90001.000000          0.000000    0.000000      0.000000
# 25%    90243.500000      19318.500000   32.400000   9763.500000
# 50%    90807.000000      31481.000000   37.100000  15283.000000
# 75%    91417.000000      44978.000000   41.000000  22219.500000
# max    93591.000000     105549.000000   74.000000  52794.000000
#
#        Total Females  Total Households  Average Household Size
# count     319.000000        319.000000              319.000000
# mean    16849.777429      10964.570533                2.828119
# std     10934.986468       6270.646400                0.835658
# min         0.000000          0.000000                0.000000
# 25%      9633.500000       6765.500000                2.435000
# ...

# %%
# idxmin() 和 idxmax() 会计算最小、最大值对应的索引标签。
df_los_census.idxmax()
# Out:
# Zip Code                  318
# Total Population          132
# Median Age                180
# Total Males                10
# Total Females             132
# Total Households           85
# Average Household Size     10
# dtype: int64

# %%
# count() 用于统计非空数据的数量。
df_los_census.count()
# Out:
# Zip Code                  319
# Total Population          319
# Median Age                319
# Total Males               319
# Total Females             319
# Total Households          319
# Average Household Size    319
# dtype: int64

# %%
# value_counts() 仅仅针对 Series，它会计算每一个值对应的数量统计
s = pd.Series(np.random.randint(0, 9, size=100)) # 生成一个 Series，并在 0-9 之间生成 100 个随机值。

print(s)
print('------分割线------')
print(s.value_counts())
# Out:
# 0     0
# 1     4
# 2     4
# 3     3
# 4     1
# 5     1
# 6     8
# 7     3
# 8     7
# 9     8
# 10    4
# 11    3
# 12    8
# 13    4
# 14    2
# 15    4
# 16    7
# 17    4
# 18    5
# 19    2
# 20    7
# 21    3
# 22    8
# 23    8
# 24    1
# 25    4
# 26    5
# 27    1
# 28    0
# 29    2
#      ..
# 70    0
# 71    1
# 72    5
# 73    8
# 74    0
# 75    7
# 76    6
# 77    8
# 78    4
# 79    6
# 80    4
# 81    5
# 82    8
# 83    5
# 84    1
# 85    7
# 86    0
# 87    3
# 88    2
# 89    8
# 90    2
# 91    7
# 92    2
# 93    5
# 94    0
# 95    0
# 96    1
# 97    3
# 98    4
# 99    3
# Length: 100, dtype: int64
# ------分割线------
# 8    16
# 3    16
# 4    13
# 1    13
# 2    12
# 0    10
# 5     9
# 7     7
# 6     4
# dtype: int64

# %%
df_los_census.sum()
# Out:
# Zip Code                  29029215.00
# Total Population          10603988.00
# Median Age                   11652.30
# Total Males                5228909.00
# Total Females              5375079.00
# Total Households           3497698.00
# Average Household Size         902.17
# dtype: float64

# %%
df_los_census.mean()
# Out:
# Zip Code                  91000.673981
# Total Population          33241.341693
# Median Age                   36.527586
# Total Males               16391.564263
# Total Females             16849.777429
# Total Households          10964.570533
# Average Household Size        2.828119
# dtype: float64

# %%
df_los_census.median()
# Out:
# Zip Code                  90807.00
# Total Population          31481.00
# Median Age                   37.10
# Total Males               15283.00
# Total Females             16202.00
# Total Households          10968.00
# Average Household Size        2.83
# dtype: float64

# %%
s = pd.Series(data=[1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])

print(s)
print('------分割线------')
print(s.reindex(['e', 'b', 'f', 'd']))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# ------分割线------
# e    5.0
# b    2.0
# f    NaN
# d    4.0
# dtype: float64

# %%
df = pd.DataFrame(data={'one': [1, 2, 3], 'two': [4, 5, 6], 'three': [7, 8, 9]}, index=['a', 'b', 'c'])
df
# Out:
#    one  two  three
# a    1    4      7
# b    2    5      8
# c    3    6      9

# %%
df.reindex(index=['b', 'c', 'a'], columns=['three', 'two', 'one'])
# Out:
#    three  two  one
# b      8    5    2
# c      9    6    3
# a      7    4    1

# %%
s.reindex(df.index)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
df = pd.DataFrame(data={'one': [1, 2, 3], 'two': [4, 5, 6], 'three': [7, 8, 9], 'four': [10, 11, 12]}, index=['a', 'c', 'b'])

df
# Out:
#    one  two  three  four
# a    1    4      7    10
# c    2    5      8    11
# b    3    6      9    12

# %%
df.sort_index()
# Out:
#    one  two  three  four
# a    1    4      7    10
# b    3    6      9    12
# c    2    5      8    11

# %%
df.sort_index(ascending=False)
# Out:
#    one  two  three  four
# c    2    5      8    11
# b    3    6      9    12
# a    1    4      7    10

# %%
df = pd.DataFrame(data={'one': [1, 2, 3, 7], 'two': [4, 5, 6, 9], 'three': [7, 8, 9, 2], 'four': [10, 11, 12, 5]}, index=['a', 'c', 'b','d'])

df
# Out:
#    one  two  three  four
# a    1    4      7    10
# c    2    5      8    11
# b    3    6      9    12
# d    7    9      2     5

# %%
df.sort_values(by="three")
# Out:
#    one  two  three  four
# d    7    9      2     5
# a    1    4      7    10
# c    2    5      8    11
# b    3    6      9    12

# %%
df[['one', 'two', 'three', 'four']].sort_values(by=['one', 'two'])
# Out:
#    one  two  three  four
# a    1    4      7    10
# c    2    5      8    11
# b    3    6      9    12
# d    7    9      2     5

# %%
df
# Out:
#    one  two  three  four
# a    1    4      7    10
# c    2    5      8    11
# b    3    6      9    12
# d    7    9      2     5
